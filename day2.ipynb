# %% [markdown]
# <a href="https://colab.research.google.com/github/krishhhXcode/SD_Krish_0050/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [1,2,3,4,45,5]
l1=[]
for i in l:
  l1.append(i**2)

# %%
print(l1)
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
[i**2 for i in l1]
# Out:
# [1, 16, 81, 256, 4100625, 625]

# %%
l
# Out:
# [1, 2, 3, 4, 45, 5]

# %%
[i for i in l if i%2==0]
# Out:
# [2, 4]

# %%
l1 = ['sudh','skills','kumar','aman']

# %%
d={"k1":1,"k2":2,"k3":3,"k4":4}

# %%
{k:v**2 for k, v in d.items()}
# Out:
# {'k1': 1, 'k2': 4, 'k3': 9, 'k4': 16}

# %%
d.items()
# Out:
# dict_items([('k1', 1), ('k2', 2), ('k3', 3), ('k4', 4)])

# %%
a
