# %% [markdown]
# <a href="https://colab.research.google.com/github/krishhhXcode/SD_Krish_0050/blob/main/Functions_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def test():
  pass

# %%
def test1():
  print("this is my frist function")

# %%
test1()
# Out:
# this is my frist function

# %%
test1() + "sudh" #changing a string is not possible
# Out:
# this is my frist function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7618/3118336650.py in <cell line: 0>()
# ----> 1 test1() + "sudh"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
  return "this is my first func"

# %%
test2()
# Out:
# 'this is my first func'

# %%
test2()+"tion"
# Out:
# 'this is my first function'

# %%
def test3():
  return "sudh",23,45.89,[1,2,3,4]

# %%
test3()
# Out:
# ('sudh', 23, 45.89, [1, 2, 3, 4])

# %%
def test4():
  a = 5+6/7
  return a

# %%
test4()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
   d= a+b/c
   return d

# %%
test5() #will not run without positional arguments
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1975/379652043.py in <cell line: 0>()
# ----> 1 test5()
#
# TypeError: test5() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
test5(3,7,7)
# Out:
# 4.0

# %%
def test6(a,b):
  return a+b

# %%
test6(3,4)
# Out:
# 7

# %%
test6("sudh","kumar")
# Out:
# 'sudhkumar'

# %%
test6([1,2,3,4,5],[3,5,6])
# Out:
# [1, 2, 3, 4, 5, 3, 5, 6]

# %%
l = [1,2,3,4,5,"sudh","kumar",[1,2,3,4,5]]

# %%
l1 =[]
for i in l:
  if type(i)==int or type (i)==str:
    l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4, 5, 'sudh', 'kumar']

# %%
def test7(a):
  l=[]
  for i in a:
    if type(i)== list:
      for j in i:
        l.append(j)
    else:
        if type(i)== int or type(i) == float:
            l.append(i)
            return l

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'sudh', 'kumar', [1, 2, 3, 4, 5]]

# %%
test7(l)
# Out:
# [1]

# %%
def test_fib(n):
  a,b=0,1
  for i in range(n):
     yield a
     a,b =b , a+b

# %%
for i in test_fib(5):
 print(i)
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
fib = test_fib(5)

# %%
print(fib)
# Out:
# <generator object test_fib at 0x7d8786ad7920>

# %%
for i in range(5):
  print (next(fib))
# Out:
# 0
# 1
# 1
# 2
# 3
