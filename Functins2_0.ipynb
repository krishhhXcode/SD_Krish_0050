# %% [markdown]
# <a href="https://colab.research.google.com/github/krishhhXcode/SD_Krish_0050/blob/main/Functins2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def test():
  pass

# %%
def test1():
  print("this is my very very first function")

# %%
test1()
# Out:
# this is my very very first function

# %%
test1()+ "sudh"
# Out:
# this is my very very first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5970/1705551427.py in <cell line: 0>()
# ----> 1 test1()+ "sudh"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
  return "this is my first func"

# %%
test2()
# Out:
# 'this is my first func'

# %%
test2()+"tion"
# Out:
# 'this is my first function'

# %%
def test3() :
      return "sudh" , 23,345.56,[1,2,3,3]

# %%
test3()
# Out:
# ('sudh', 23, 345.56, [1, 2, 3, 3])

# %%
def test4():
    a=5+6/7
    return a

# %%
test4()
# Out:
# 5.857142857142857

# %%
def test5(a, b, c):
    d = a+b/c
    return d

# %%
test5()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5970/379652043.py in <cell line: 0>()
# ----> 1 test5()
#
# TypeError: test5() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
test5(2,5,8)
# Out:
# 2.625

# %%
def test6(a,b):
    return a+b

# %%
def test6(a,b,c):
    return a+b+c

# %%
test6(3,4,"")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5970/1642401226.py in <cell line: 0>()
# ----> 1 test6(3,4,"ritu")
#
# /tmp/ipykernel_5970/1049204927.py in test6(a, b, c)
#       1 def test6(a,b,c):
# ----> 2     return a+b+c
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
test6([1,2,3,4,5],[4,5,6])
# Out:
# [1, 2, 3, 4, 5, 4, 5, 6]

# %%
test6((1,2,3,4,5),(4,5,6))
# Out:
# (1, 2, 3, 4, 5, 4, 5, 6)

# %%
l=[1,2,3,5,"sudh","kumar",[1,2,3,4,5,6]]

# %%
l1=[]
for i in l :
    if type(i) == int or type(i) == float :
        l1.append(i)

# %%
l1
# Out:
# [1, 2, 3]

# %%
def test8(a):
  l=[]
  for i in a:
    if type(i) == list:
        for j in i :
            l.append(j)
    else :
         if type(i) == int or type(i) == float:
            l.append(i)
  return l

# %%
l
# Out:
# [1, 2, 3, 5, 'sudh', 'kumar', [1, 2, 3, 4, 5, 6]]

# %%
test8(l)
# Out:
# [1, 2, 3, 5, 1, 2, 3, 4, 5, 6]

# %%
def test_fib(n):
  a,b=0,1
  for i in range(n):
    yield a
    a,b = b,a+b

# %%
for i in test_fib(5):
   print(i)
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
fib = test_fib(5)

# %%
print(fib)
# Out:
# <generator object test_fib at 0x7c4206c0b4c0>

# %%
for i in range(10):
   print(next(fib))
# Out:
# 0
# 1
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_5970/1715809451.py in <cell line: 0>()
#       1 for i in range(10):
# ----> 2    print(next(fib))
#
# StopIteration:

# %%
s="sudh"

# %%
s1 = iter(s)

# %%
type(s1)
# Out:
# str_ascii_iterator

# %%
next(s1)
# Out:
# 's'

# %%
next(s1)
# Out:
# 'u'

# %%
def count_digits(n):
  if n == 0:
    return 1
  else :
    return len(str(abs(n)))

# %%
c = count_test(15)

# %%
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14209/1152398069.py in <cell line: 0>()
# ----> 1 print(d)
#
# NameError: name 'd' is not defined

# %%
type(c)
# Out:
# NoneType

# %%
n = 3
p = 2

# %%
def test(n,p):
  return n**p

# %%
test(3,2)
# Out:
# 9

# %%
a = lambda n,p : n**p

# %%
a(3,5)
# Out:
# 243

# %%
add = lambda x,y,z,b : x+y+z+b

# %%
add(3,4,5,6)
# Out:
# 18

# %%
c_to_f = lambda c : (9/5)*c + 32

# %%
c_to_f(45)
# Out:
# 113.0

# %%
finding_max = lambda x,y : x if x>y else y

# %%
finding_max(12,23)
# Out:
# 23

# %%
s = "skills"

# %%
find_len = lambda s : len(s)

# %%
find_len(s)
# Out:
# 6

# %%
l=[2,3,4,5,6]

# %%
l
# Out:
# [2, 3, 4, 5, 6]

# %%
def sq(x):
  return x**2

# %%
list(map(sq , l))
# Out:
# [4, 9, 16, 25, 36]

# %%
list(map(lambda x : x**2 , l))
# Out:
# [4, 9, 16, 25, 36]

# %%
def test(l):
  l1 = []
  for i in l:
    l1.append(i**2)
  return l1

# %%
test(l)
# Out:
# [4, 9, 16, 25, 36]

# %%
l
# Out:
# [2, 3, 4, 5, 6]

# %%
def sq(x):
  return x**2

# %%
list(map(sq , l))
# Out:
# [4, 9, 16, 25, 36]

# %%
list(map(lambda x : x**2 , l))
# Out:
# [4, 9, 16, 25, 36]

# %%
l1 = [1,2,3,4,5]
l2 = [6,7,8,9,10]

list(map(lambda x,y : x+y , l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
def add(x,y):
  return x+y

# %%
list(map(add , l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
l = [1,2,3,4,5]

# %%
reduce(lambda x,y : x+y , [])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3487/1781114009.py in <cell line: 0>()
# ----> 1 reduce(lambda x,y : x+y , [])
#
# NameError: name 'reduce' is not defined

# %%
reduce(lambda x,y : x+y , [])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3487/1781114009.py in <cell line: 0>()
# ----> 1 reduce(lambda x,y : x+y , [])
#
# NameError: name 'reduce' is not defined

# %%
class skills:

  def welcome_msg(self):
    print("welcome to skill")

# %%
rohan = skills()

# %%
print(type(rohan))
# Out:
# <class '__main__.skills'>

# %%
rohan.welcome_msg()
# Out:
# welcome to skill

# %%
gaurav = skills()

# %%
gaurav . welcome_msg()
# Out:
# welcome to skill

# %%
class skills1:

  def __init__(self , phone_number , email_id , student_id):
    self.phone_number = phone_number
    self.email_id = email_id
    self.student_id = student_id

  def return_student_details(self):
    return self.student_id , self.phone_number , self.email_id

# %%
rohan = skills1(8081421408, "rohan@gmail.com" , 101)

# %%
rohan.phone_number
# Out:
# 8081421408

# %%
rohan.email_id
# Out:
# 'rohan@gmail.com'

# %%
rohan.return_student_details()
# Out:
# (101, 8081421408, 'rohan@gmail.com')

# %%
gaurav = skills1(8081421408, "gaurav@gmail.com" , 102)

# %%
gaurav.phone_number
# Out:
# 8081421408

# %%
gaurav.email_id
# Out:
# 'gaurav@gmail.com'

# %%
class UPI:
  def pay(self):
      print("payment  through UPI")

class card:
     def pay(self):
        print("payment through card")

for payment in [UPI(), card()]:
    payment.pay()
# Out:
# payment  through UPI
# payment through card

# %%
users = {}


n = int(input("How many users do you want to add? "))

for i in range(n):
    name = input("Enter username: ")
    password = int(input("Enter password: "))
    users[name] = password

print("\nUsers saved successfully!")


print("\n----- LOGIN -----")
login_name = input("Enter your username: ")

if login_name in users:
    login_password = int(input("Enter your password: "))

    if users[login_name] == login_password:
        print("Welcome to the tracker!")
        Expense = input("enter your expense: colthing,food,recharge")

    else:
        print("Incorrect password.")
else:
    print("Username not found.")
# Out:
# How many users do you want to add? 1
# Enter username: aman
# Enter password: 8081
#
# Users saved successfully!
#
# ----- LOGIN -----
# Enter your username: aman
# Enter your password: 8081
# Welcome to the tracker!
